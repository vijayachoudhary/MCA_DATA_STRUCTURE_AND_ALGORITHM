# %%
arr = [10, 20, 30, 40, 50]

value = int(input("Enter value: "))
index = arr.index(value)
print("Index is:", index)
# Out:
# Index is: 2

# %%
arr = [10, 20, 30, 40,60]
for i in range(len(arr)):
    print(i,arr[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 60

# %%
arr = [10, 20, 30, 40, 50]

value = int(input("Enter value: "))

for i in range(len(arr)):
    if arr[i] == value:
        print(i)
# Out:
# 3

# %%
arr = [10, 20, 30, 40,60]
for i in range(len(arr)):
    print(i,arr[i],id(arr[i]))
# Out:
# 0 10 140721323287960
# 1 20 140721323288280
# 2 30 140721323288600
# 3 40 140721323288920
# 4 60 140721323289560

# %%
from array import array
arr=array('i',[10,20,30,40])
print("Memory Address:")
for i in range (len(arr)):
    print(f"index{i}->Address{arr.buffer_info()[0]+i*arr.itemsize}")
# Out:
# Memory Address:
# index0->Address1940438856576
# index1->Address1940438856580
# index2->Address1940438856584
# index3->Address1940438856588
